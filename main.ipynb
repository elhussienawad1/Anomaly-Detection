# %%
# In your notebook
from pyspark.sql import SparkSession
import glob
from src.hadoop_preprocessing import parse_hadoop_logs
spark = SparkSession.builder.appName("test").getOrCreate()

hadoop_files = glob.glob("Data/Hadoop_log/Hadoop_log/application_1445062781478_0011/*.log")
processed = []

for file in hadoop_files:
    df = parse_hadoop_logs(spark, file)
    count = df.count()
    processed.append((file, count))

print(len(processed))  # should be 14
print(processed)


# df.printSchema()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/05/03 13:18:46 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 # In your notebook
#       2 from pyspark.sql import SparkSession
#       3 import glob
#       4 from src.hadoop_preprocessing import parse_hadoop_logs
# ----> 5 spark = SparkSession.builder.appName("test").getOrCreate()
#       6
#       7 hadoop_files = glob.glob("Data/Hadoop_log/Hadoop_log/application_1445062781478_0011/*.log")
#       8 processed = []
#
# File ~/Desktop/BigDataProj/Anomaly-Detection/SparkEnv/lib/python3.12/site-packages/pyspark/sql/session.py:560, in SparkSession.Builder.getOrCreate(self)
#     557     sc = SparkContext.getOrCreate(sparkConf)
#     558     # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     559     # by all sessions.
# --> 560     session = SparkSession(sc, options=self._options)
#     561 else:
#     562     module = SparkSession._get_j_spark_session_module(session._jvm)
#
# File ~/Desktop/BigDataProj/Anomaly-Detection/SparkEnv/lib/python3.12/site-packages/pyspark/sql/session.py:636, in SparkSession.__init__(self, sparkContext, jsparkSession, options)
#     632 jSparkSessionModule = SparkSession._get_j_spark_session_module(self._jvm)
#     634 if jsparkSession is None:
#     635     if (
# --> 636         jSparkSessionClass.getDefaultSession().isDefined()
#     637         and not jSparkSessionClass.getDefaultSession().get().sparkContext().isStopped()
#     638     ):
#     639         jsparkSession = jSparkSessionClass.getDefaultSession().get()
#     640         jSparkSessionModule.applyModifiableSettings(jsparkSession, options)
#
# TypeError: 'JavaPackage' object is not callable
